# %%
import pandas as pd
import numpy as np
import seaborn as sea
from matplotlib import pyplot as plt


sea.set_style('darkgrid')

df =pd.read_csv('C://Users//Librarian//GitHub//Upgrad//Data-Science//Projects//GDP_Analysis/data_set_1_a.csv')

del df['West Bengal1']
#print(df[df['Items  Description'] == '(% Growth over previous year)'])
#df = df[df['Items  Description'] != '(% Growth over previous year)']
df_after_growth_removal = df[(df['Items  Description'] == 'GSDP - CURRENT PRICES (` in Crore)') & (df['Duration'] != '2016-17')]
df_growth_percent = df[df['Items  Description'] == '(% Growth over previous year)']
df_growth_percent
df_mean_growth = df_growth_percent[(df_growth_percent['Duration']!='2012-13') & (df_growth_percent['Duration']!='2016-17')]

test = pd.DataFrame(df_mean_growth.mean())
test.columns =['Statewise_GDP_Growth']
test = test.sort_values(by = 'Statewise_GDP_Growth',ascending = False)
plt.figure(num = None, figsize = (30,16), dpi = 80, facecolor = 'w', edgecolor='k')
test.plot(kind = 'bar')
#mean_growth = pd.DataFrame(df_mean_growth.mean())
#mean_growth.columns= ['State','Growth_Percent']

print("Northeastern states seems to be doing better (1.Mizoram 2.Tripura 3.Nagaland )")
print(test[:5])
## Kerala have a growht percent of 12.58 its doing much better than the national average of 11.20

gdp_2015 = df[(df['Items  Description'] == 'GSDP - CURRENT PRICES (` in Crore)') & (df['Duration'] == '2015-16')]
a_t = pd.DataFrame(gdp_2015.transpose())
a_t = a_t[2:]

a_t.columns = ['State_GDP']
a_t = a_t.sort_values(by = 'State_GDP',ascending = False)
a_t.plot(kind = 'bar')

## Of all the ones where data is available top five are 
print("\n\n")
print("Bottom Five by GDP")
print(a_t.sort_values(by = 'State_GDP')[0:5])
print("\n\n")
print("Top Five by GDP")
print(a_t.sort_values(by = 'State_GDP',ascending = False)[1:6])
# Out:
# Northeastern states seems to be doing better (1.Mizoram 2.Tripura 3.Nagaland )
#                    Statewise_GDP_Growth
# Mizoram                       17.700000
# Tripura                       17.030000
# Nagaland                      16.415000
# Manipur                       14.610000
# Arunachal Pradesh             14.413333
#
#
#
# Bottom Five by GDP
#                   State_GDP
# Sikkim                16637
# Arunachal Pradesh     18784
# Puducherry            26533
# Meghalaya             26745
# Chandigarh            30304
#
#
#
# Top Five by GDP
#                    State_GDP
# Tamil Nadu       1.21267e+06
# Uttar Pradesh     1.1538e+06
# Karnataka        1.02707e+06
# Gujarat               994316
# Andhra Pradesh        609934

# %%
import pandas as pd
import glob as gb

result = pd.DataFrame()
path = "C://Users//Librarian//GitHub//Upgrad//Data-Science//Projects//GDP_Analysis//New Folder//Backup//*.csv"
#df  = pd.read_csv('C://Users//Librarian//GitHub//Upgrad//Data-Science//Projects//GDP_Analysis//New Folder//Backup//NAD-Andhra_Pradesh-GSVA_cur_2016-17.csv')
for filename in gb.glob(path):
    #print(filename)
    state = filename.split("-")[2]
    #print(state)
    df = pd.read_csv(filename,encoding = "ISO-8859-1")
    df = df[['S.No.', 'Item','2014-15']]
    df['State'] = state
    result = result.append(df)

result = result[(result['State']!='Delhi') & (result['State']!='Chandigarh')&(result['State']!='Puducherry')]

# %%
import seaborn as sea
from matplotlib import pyplot as plt

plt.figure(num = None, figsize = (60,16), dpi = 80, facecolor = 'w', edgecolor='k')


states = list(result.State.unique())
#print(states)
#['S.No.', 'Item', '2014-15', 'State']
df_gdp = result[result.Item == 'Per Capita GSDP (Rs.)']
df_gdp.columns
gdp_state_wise = df_gdp[['State','2014-15']]
gdp_state_wise.columns= ['State','GDP_2014_2015']
gdp_state_wise = gdp_state_wise[(gdp_state_wise['State']!='Delhi') & (gdp_state_wise['State']!='Chandigarh')&(gdp_state_wise['State']!='Puducherry')]
gdp_state_wise = gdp_state_wise.sort_values('GDP_2014_2015',ascending = False)
sea.barplot(x = 'State', y = 'GDP_2014_2015', data = gdp_state_wise)
#gdp_state_wise
print("\n\n")
print("Top and Bottom 5 are: -")
print(gdp_state_wise[:5])
print("\n\n")
print(gdp_state_wise[-5:].sort_values('GDP_2014_2015'))

print("\n\n\n")
print("Ratio of highest to lowest is ")
print(int(gdp_state_wise['GDP_2014_2015'].iloc[0])/int(gdp_state_wise['GDP_2014_2015'].iloc[-1]))
# Out:
# Top and Bottom 5 are: -
#           State  GDP_2014_2015
# 32          Goa       271793.0
# 32       Sikkim       240274.0
# 32      Haryana       164077.0
# 32       Kerala       154778.0
# 32  Uttarakhand       153076.0
#
#
#
#             State  GDP_2014_2015
# 32          Bihar        33954.0
# 32  Uttar_Pradesh        49450.0
# 32        Manipur        58442.0
# 32          Assam        60621.0
# 32      Jharkhand        62091.0
#
#
#
#
# Ratio of highest to lowest is
# 8.004741709371503

# %%
#colors = ["#006D2C", "#31A354","#74C476"]
sector_wise_division = result[(result['Item']=='Primary') | (result['Item'] == 'Secondary') | (result['Item'] == 'Tertiary')]
pivot_df = sector_wise_division.pivot(index='State', columns='Item', values='2014-15')
pivot_df
pivot_df.plot.bar(stacked=True, figsize=(15,10))
# Out:
# Item                  Primary   Secondary    Tertiary
# State
# Andhra_Pradesh     16303716.0  10488884.0  22032942.0
# Arunachal_Pradesh    716959.0    287489.0    631844.0
# Assam               5326697.0   4033091.0   9307109.0
# Bihar               8019997.0   5984896.0  22179969.0
# Chhattisgarh        6400817.0   8238886.0   7588778.0
# Goa                  312129.0   1547536.0   1738217.0
# Gujarat            15887187.0  33023538.0  30220377.0
# Haryana             8040424.0  12561411.0  19226568.0
# Himachal_Pradesh    1548366.0   4119162.0   4133326.0
# Jharkhand           5248354.0   6241471.0   8133341.0
# Karnataka          12066304.0  20484404.0  50490630.0
# Kerala              6489442.0  12070040.0  29673778.0
# Madhya_Pradesh     17854020.0  10044889.0  18117360.0
# Maharashtra        21758383.0  47445207.0  88631076.0
# Manipur              383140.0    220173.0   1177334.0
# Meghalaya            451050.0    637942.0   1200655.0
# Mizoram              225598.0    270072.0    637619.0
# Nagaland             616178.0    212361.0    992956.0
# Odisha              9009306.0   8989693.0  12256258.0
# Punjab              9296070.0   7904914.0  16717805.0
# Rajasthan          19113780.0  13028794.0  26015812.0
# Sikkim               138776.0    845253.0    483103.0
# Tamil_Nadu         13329774.0  32841892.0  53343788.0
# Telangana           9133354.0   9924001.0  28471410.0
# Tripura              942216.0    484393.0   1484709.0
# Uttar_Pradesh      25999255.0  25548724.0  45968959.0
# Uttarakhand         1845972.0   7642865.0   5587975.0

# %%
exclude = ['Tertiary','TOTAL GSVA at basic prices',
'Taxes on Products',
'Subsidies on products',
'Gross State Domestic Product',
"Population ('00)",
'Secondary',
'Primary',
]
#result[~result['Items  Description'].isin(exclude)]
sub_sector_data = result[result['Item'].isin(exclude) == False]
df_gdp = result[result.Item == 'Per Capita GSDP (Rs.)']
df_gdp = df_gdp[['2014-15','State']]
df_gdp.sort_values(by = '2014-15')

pivot_df = pd.DataFrame(sub_sector_data.pivot(index='State', columns='Item', values='2014-15'))
pivot_df['Sector'] = 'C4'
pivot_df['Sector'][pivot_df['Per Capita GSDP (Rs.)'].quantile(0.2) < pivot_df['Per Capita GSDP (Rs.)']] = "C3"
pivot_df['Sector'][pivot_df['Per Capita GSDP (Rs.)'].quantile(0.5) < pivot_df['Per Capita GSDP (Rs.)']] = "C2"
pivot_df['Sector'][pivot_df['Per Capita GSDP (Rs.)'].quantile(0.85) < pivot_df['Per Capita GSDP (Rs.)']] = "C1"
#pivot_df[pivot_df['Sector'] == 'C1']
#pivot_df.columns
pivot_df.drop(['Per Capita GSDP (Rs.)'], axis=1)
pivot_df
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Item               Agriculture, forestry and fishing  Air transport  \
# State
# Andhra_Pradesh                            14819416.0        14900.0
# Arunachal_Pradesh                           686117.0            0.0
# Assam                                      3855548.0        26223.0
# Bihar                                      7951890.0        13599.0
# Chhattisgarh                               3948847.0         9507.0
# Goa                                         308507.0        46359.0
# Gujarat                                   13769969.0            NaN
# Haryana                                    8015238.0            NaN
# Himachal_Pradesh                           1514981.0         3979.0
# Jharkhand                                  3211065.0         6716.0
# Karnataka                                 11219422.0       171785.0
# Kerala                                     5930617.0       125029.0
# Madhya_Pradesh                            16235647.0        26746.0
# Maharashtra                               16475655.0       174188.0
# Manipur                                     383140.0         6288.0
# Meghalaya                                   366521.0         1443.0
# Mizoram                                     217010.0          144.0
# Nagaland                                    607897.0         4153.0
# Odisha                                     6422978.0        15354.0
# Punjab                                     9285716.0         4473.0
# Rajasthan                                 15044394.0        13469.0
# Sikkim                                      137447.0            0.0
# Tamil_Nadu                                13064238.0       180836.0
# Telangana                                  7591501.0       120691.0
# Tripura                                     799825.0            NaN
# Uttar_Pradesh                             25097754.0        36582.0
# Uttarakhand                                1601423.0         3889.0
#
# Item               Communication & services related to broadcasting  \
# State
# Andhra_Pradesh                                             928756.0
# Arunachal_Pradesh                                           19568.0
# Assam                                                      357619.0
# Bihar                                                      919427.0
# Chhattisgarh                                               294552.0
# Goa                                                         44028.0
# Gujarat                                                   1242520.0
# Haryana                                                    479658.0
# Himachal_Pradesh                                           194266.0
# Jharkhand                                                  323214.0
# Karnataka                                                 1349520.0
# Kerala                                                     884767.0
# Madhya_Pradesh                                             905381.0
# Maharashtra                                               2551115.0
# Manipur                                                     42017.0
# Meghalaya                                                   40547.0
# Mizoram                                                     17395.0
# Nagaland                                                    37794.0
# Odisha                                                     513531.0
# Punjab                                                     660819.0
# Rajasthan                                                 1150955.0
# Sikkim                                                      12064.0
# Tamil_Nadu                                                1903283.0
# Telangana                                                  753992.0
# Tripura                                                     66676.0
# Uttar_Pradesh                                             1914737.0
# Uttarakhand                                                733778.0
#
# Item               Construction       Crops  \
# State
# Andhra_Pradesh        4664889.0   7893514.0
# Arunachal_Pradesh      147842.0    415520.0
# Assam                 1733568.0   2890544.0
# Bihar                 3449763.0   4688237.0
# Chhattisgarh          2669855.0   2613371.0
# Goa                    165819.0    140421.0
# Gujarat               5526017.0   9671086.0
# Haryana               3702571.0   4636731.0
# Himachal_Pradesh       808256.0    853758.0
# Jharkhand             1789834.0   2094466.0
# Karnataka             6104799.0   8157179.0
# Kerala                7314003.0   3070386.0
# Madhya_Pradesh        4403151.0  13216013.0
# Maharashtra           9450211.0  10435121.0
# Manipur                143182.0    226583.0
# Meghalaya              150256.0    223330.0
# Mizoram                133228.0    116609.0
# Nagaland               156072.0    375825.0
# Odisha                2402396.0   4382636.0
# Punjab                2202962.0   5690972.0
# Rajasthan             5353326.0   7673441.0
# Sikkim                  82058.0    114976.0
# Tamil_Nadu           12216718.0   7297820.0
# Telangana             2854024.0   4162493.0
# Tripura                177899.0    397591.0
# Uttar_Pradesh        11256450.0  16215212.0
# Uttarakhand           1342733.0    866146.0
#
# Item               Electricity, gas, water supply & other utility services  \
# State
# Andhra_Pradesh                                             1151729.0
# Arunachal_Pradesh                                           113527.0
# Assam                                                       296587.0
# Bihar                                                       345168.0
# Chhattisgarh                                               1198438.0
# Goa                                                         204110.0
# Gujarat                                                    3409983.0
# Haryana                                                    1101919.0
# Himachal_Pradesh                                            767268.0
# Jharkhand                                                   337489.0
# Karnataka                                                  1425762.0
# Kerala                                                      482470.0
# Madhya_Pradesh                                             1272905.0
# Maharashtra                                                4334702.0
# Manipur                                                      27490.0
# Meghalaya                                                    54473.0
# Mizoram                                                     128365.0
# Nagaland                                                     37944.0
# Odisha                                                      833067.0
# Punjab                                                      911611.0
# Rajasthan                                                  1122888.0
# Sikkim                                                      212499.0
# Tamil_Nadu                                                 1710379.0
# Telangana                                                   716266.0
# Tripura                                                      77870.0
# Uttar_Pradesh                                              2030625.0
# Uttarakhand                                                 433880.0
#
# Item               Financial services  Fishing and aquaculture  \
# State
# Andhra_Pradesh              1900863.0                2270664.0
# Arunachal_Pradesh             25207.0                   8193.0
# Assam                        543651.0                 529539.0
# Bihar                       1178022.0                 653224.0
# Chhattisgarh                 739057.0                 385483.0
# Goa                          233618.0                 122201.0
# Gujarat                     4606644.0                 638357.0
# Haryana                     1671486.0                 110080.0
# Himachal_Pradesh             362521.0                   9968.0
# Jharkhand                    551441.0                 108947.0
# Karnataka                   4094169.0                 500390.0
# Kerala                      2010306.0                 704319.0
# Madhya_Pradesh              1988794.0                 121277.0
# Maharashtra                16143324.0                 475141.0
# Manipur                       30315.0                  35243.0
# Meghalaya                     64091.0                   9583.0
# Mizoram                       23168.0                   7048.0
# Nagaland                      60393.0                   8470.0
# Odisha                      1065147.0                 460636.0
# Punjab                      2057520.0                 107657.0
# Rajasthan                   1827413.0                  58036.0
# Sikkim                        21079.0                    604.0
# Tamil_Nadu                  5598498.0                 680352.0
# Telangana                   3023729.0                 266968.0
# Tripura                       86094.0                 168961.0
# Uttar_Pradesh               3392275.0                 380730.0
# Uttarakhand                  385030.0                   4796.0
#
# Item               Forestry and logging  Hotels & restaurants  ...  \
# State                                                          ...
# Andhra_Pradesh                 346160.0              517400.0  ...
# Arunachal_Pradesh              224017.0                3625.0  ...
# Assam                          261987.0              110904.0  ...
# Bihar                          550132.0              366982.0  ...
# Chhattisgarh                   597785.0              121407.0  ...
# Goa                             15744.0               37434.0  ...
# Gujarat                        761616.0                   NaN  ...
# Haryana                        352254.0              168535.0  ...
# Himachal_Pradesh               540950.0              121333.0  ...
# Jharkhand                      445149.0              151163.0  ...
# Karnataka                      693082.0             1467938.0  ...
# Kerala                         499808.0              793498.0  ...
# Madhya_Pradesh                 965588.0              303890.0  ...
# Maharashtra                   1592564.0             1552198.0  ...
# Manipur                         45831.0                9313.0  ...
# Meghalaya                       61166.0               26247.0  ...
# Mizoram                         47763.0                2991.0  ...
# Nagaland                        99802.0                6607.0  ...
# Odisha                         791463.0              262766.0  ...
# Punjab                         848245.0              218667.0  ...
# Rajasthan                     1956660.0              354543.0  ...
# Sikkim                           4529.0                5945.0  ...
# Tamil_Nadu                     392705.0             1643253.0  ...
# Telangana                      210741.0              770479.0  ...
# Tripura                        145096.0                   NaN  ...
# Uttar_Pradesh                 1404936.0              961104.0  ...
# Uttarakhand                    339293.0              209033.0  ...
#
# Item               Road transport**  Services incidental to transport  \
# State
# Andhra_Pradesh                  NaN                          780200.0
# Arunachal_Pradesh               NaN                             109.0
# Assam                           NaN                           35739.0
# Bihar                           NaN                          166600.0
# Chhattisgarh                    NaN                            5232.0
# Goa                             NaN                           19272.0
# Gujarat                         NaN                               NaN
# Haryana                         NaN                          190269.0
# Himachal_Pradesh                NaN                            1724.0
# Jharkhand                       NaN                           17436.0
# Karnataka                       NaN                           55349.0
# Kerala                    2761427.0                           71567.0
# Madhya_Pradesh                  NaN                           36694.0
# Maharashtra                     NaN                         1175023.0
# Manipur                         NaN                            2441.0
# Meghalaya                       NaN                               NaN
# Mizoram                         NaN                               0.0
# Nagaland                        NaN                               0.0
# Odisha                          NaN                          117469.0
# Punjab                          NaN                           48124.0
# Rajasthan                       NaN                           47609.0
# Sikkim                          NaN                               0.0
# Tamil_Nadu                      NaN                               NaN
# Telangana                       NaN                          454909.0
# Tripura                         NaN                               NaN
# Uttar_Pradesh                   NaN                           16323.0
# Uttarakhand                     NaN                             -76.0
#
# Item               Services incidental to transport*   Storage  \
# State
# Andhra_Pradesh                                   NaN   18700.0
# Arunachal_Pradesh                                NaN       0.0
# Assam                                            NaN   10308.0
# Bihar                                            NaN   10618.0
# Chhattisgarh                                     NaN   16675.0
# Goa                                              NaN     357.0
# Gujarat                                    2744163.0   57634.0
# Haryana                                          NaN   14459.0
# Himachal_Pradesh                                 NaN     129.0
# Jharkhand                                        NaN     306.0
# Karnataka                                        NaN   42787.0
# Kerala                                           NaN    3290.0
# Madhya_Pradesh                                   NaN   29012.0
# Maharashtra                                      NaN  131237.0
# Manipur                                          NaN       NaN
# Meghalaya                                        NaN     416.0
# Mizoram                                          NaN       0.0
# Nagaland                                         NaN      89.0
# Odisha                                           NaN   22675.0
# Punjab                                           NaN   76429.0
# Rajasthan                                        NaN   16584.0
# Sikkim                                           NaN       0.0
# Tamil_Nadu                                  864407.0   39834.0
# Telangana                                        NaN   19805.0
# Tripura                                      88721.0     254.0
# Uttar_Pradesh                                    NaN  171696.0
# Uttarakhand                                      NaN     660.0
#
# Item               Trade & repair services  Trade & repair services*  \
# State
# Andhra_Pradesh                   3716000.0                       NaN
# Arunachal_Pradesh                  56796.0                       NaN
# Assam                            2876251.0                       NaN
# Bihar                            7081391.0                       NaN
# Chhattisgarh                     1414164.0                       NaN
# Goa                               343492.0                       NaN
# Gujarat                         10178713.0                       NaN
# Haryana                          4817784.0                       NaN
# Himachal_Pradesh                  494162.0                       NaN
# Jharkhand                        1840196.0                       NaN
# Karnataka                        7523720.0                       NaN
# Kerala                                 NaN                 7763847.0
# Madhya_Pradesh                   5053625.0                       NaN
# Maharashtra                     14286902.0                       NaN
# Manipur                           253637.0                       NaN
# Meghalaya                         357727.0                       NaN
# Mizoram                           111324.0                       NaN
# Nagaland                          134174.0                       NaN
# Odisha                           2886789.0                       NaN
# Punjab                           4201252.0                       NaN
# Rajasthan                        6942748.0                       NaN
# Sikkim                             64624.0                       NaN
# Tamil_Nadu                      11252588.0                       NaN
# Telangana                        5724128.0                       NaN
# Tripura                           390423.0                       NaN
# Uttar_Pradesh                    8476139.0                       NaN
# Uttarakhand                      1534073.0                       NaN
#
# Item               Trade, repair, hotels and restaurants  \
# State
# Andhra_Pradesh                                 4233400.0
# Arunachal_Pradesh                                60421.0
# Assam                                          2987155.0
# Bihar                                          7448373.0
# Chhattisgarh                                   1535571.0
# Goa                                             380927.0
# Gujarat                                       10178713.0
# Haryana                                        4986319.0
# Himachal_Pradesh                                615496.0
# Jharkhand                                      1991359.0
# Karnataka                                      8991658.0
# Kerala                                         8557345.0
# Madhya_Pradesh                                 5357515.0
# Maharashtra                                   15839100.0
# Manipur                                         262950.0
# Meghalaya                                       383974.0
# Mizoram                                         114315.0
# Nagaland                                        140781.0
# Odisha                                         3149555.0
# Punjab                                         4419919.0
# Rajasthan                                      7297290.0
# Sikkim                                           70568.0
# Tamil_Nadu                                    12895842.0
# Telangana                                      6494607.0
# Tripura                                         390423.0
# Uttar_Pradesh                                  9437243.0
# Uttarakhand                                    1743106.0
#
# Item               Transport, storage, communication & services related to broadcasting  \
# State
# Andhra_Pradesh                                             5076984.0
# Arunachal_Pradesh                                            35203.0
# Assam                                                      1194568.0
# Bihar                                                      3147173.0
# Chhattisgarh                                                871770.0
# Goa                                                         189656.0
# Gujarat                                                    4555910.0
# Haryana                                                    2560623.0
# Himachal_Pradesh                                            552234.0
# Jharkhand                                                  1470022.0
# Karnataka                                                  5097652.0
# Kerala                                                     4020934.0
# Madhya_Pradesh                                             2865802.0
# Maharashtra                                                9697246.0
# Manipur                                                     109726.0
# Meghalaya                                                   148189.0
# Mizoram                                                      52587.0
# Nagaland                                                     77521.0
# Odisha                                                     2034016.0
# Punjab                                                     1951809.0
# Rajasthan                                                  3814461.0
# Sikkim                                                       47347.0
# Tamil_Nadu                                                 7188320.0
# Telangana                                                  3604741.0
# Tripura                                                     155956.0
# Uttar_Pradesh                                              7404509.0
# Uttarakhand                                                1066693.0
#
# Item               Water transport  Sector
# State
# Andhra_Pradesh             94200.0      C3
# Arunachal_Pradesh              0.0      C2
# Assam                       4502.0      C4
# Bihar                       2228.0      C4
# Chhattisgarh                   0.0      C3
# Goa                        17820.0      C1
# Gujarat                        NaN      C2
# Haryana                        NaN      C1
# Himachal_Pradesh               0.0      C2
# Jharkhand                      0.0      C4
# Karnataka                  24152.0      C2
# Kerala                     26956.0      C1
# Madhya_Pradesh                 0.0      C4
# Maharashtra               223626.0      C2
# Manipur                        NaN      C4
# Meghalaya                      NaN      C3
# Mizoram                      331.0      C3
# Nagaland                     600.0      C3
# Odisha                     50349.0      C3
# Punjab                         0.0      C2
# Rajasthan                      0.0      C3
# Sikkim                         0.0      C1
# Tamil_Nadu                 70414.0      C2
# Telangana                      0.0      C2
# Tripura                        NaN      C3
# Uttar_Pradesh                681.0      C4
# Uttarakhand                    NaN      C2
#
# [27 rows x 30 columns]

# %%
sub_sector = pivot_df.groupby('Sector').sum()
sub_sector.pivot_df()
#sub_sector.plot.bar(stacked=True, figsize=(15,10))
# Out:
# Item    Agriculture, forestry and fishing  Air transport  \
# Sector
# C1                             14391809.0       171388.0
# C2                             75209022.0       659841.0
# C3                             42226888.0        58970.0
# C4                             56735044.0       116154.0
#
# Item    Communication & services related to broadcasting  Construction  \
# Sector
# C1                                             1420517.0    11264451.0
# C2                                             9408861.0    40653562.0
# C3                                             3050206.0    15707921.0
# C4                                             4462395.0    22775948.0
#
# Item         Crops  Electricity, gas, water supply & other utility services  \
# Sector
# C1       7962514.0                                          2000998.0
# C2      47550095.0                                         13823378.0
# C3      23676317.0                                          4604774.0
# C4      39331055.0                                          4310264.0
#
# Item    Financial services  Fishing and aquaculture  Forestry and logging  \
# Sector
# C1               3936489.0                 937204.0              872335.0
# C2              36296642.0                2691822.0             5603213.0
# C3               5766226.0                3368881.0             4045895.0
# C4               7684498.0                1828960.0             3673623.0
#
# Item    Hotels & restaurants  ...  Road transport*  Road transport**  \
# Sector                        ...
# C1                 1005412.0  ...              0.0         2761427.0
# C2                 5986526.0  ...         307147.0               0.0
# C3                 1291961.0  ...              0.0               0.0
# C4                 1903356.0  ...              0.0               0.0
#
# Item    Services incidental to transport  Services incidental to transport*  \
# Sector
# C1                              281108.0                                0.0
# C2                             1735162.0                          3608570.0
# C3                              950510.0                            88721.0
# C4                              275233.0                                0.0
#
# Item     Storage  Trade & repair services  Trade & repair services*  \
# Sector
# C1       18106.0                5225900.0                 7763847.0
# C2      368515.0               55252334.0                       0.0
# C3       75393.0               15953349.0                       0.0
# C4      221940.0               25581239.0                       0.0
#
# Item    Trade, repair, hotels and restaurants  \
# Sector
# C1                                 13995159.0
# C2                                 61238862.0
# C3                                 17245309.0
# C4                                 27484595.0
#
# Item    Transport, storage, communication & services related to broadcasting  \
# Sector
# C1                                              6818560.0
# C2                                             33749808.0
# C3                                             12231484.0
# C4                                             16191800.0
#
# Item    Water transport
# Sector
# C1              44776.0
# C2             318192.0
# C3             145480.0
# C4               7411.0
#
# [4 rows x 29 columns]
